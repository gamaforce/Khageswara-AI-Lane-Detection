# %% [markdown]
# # Training Model

# %% [markdown]
# Library Import

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import datetime
import random
import numpy as np
import io
import math
import cv2
import glob
import albumentations as albu
from sklearn.model_selection import train_test_split
from pathlib import Path
from time import time as timer

# %% [markdown]
# Hyperparameter

# %%
# Training parameter
test_size = 0.2
random_seed = 42

# Hyperparameter
epoch = 80
batch_size = 32
learning_rate = 0.001
n_encoder_decoder = 1
initial_filter = 8
image_size = (720, 720)

# Augmentation
transformations = [albu.HorizontalFlip(p=0.5),
                   albu.VerticalFlip(p=0.5),
                   albu.ShiftScaleRotate(p=0.5, border_mode=1),
                   albu.RandomBrightnessContrast(p=0.25),
                   albu.RandomGamma(p=0.25)
                   ]

aug = albu.Compose(transformations)

# %% [markdown]
# Data Generator

# %%
# Data Generator
class data_generator(tf.keras.utils.Sequence):
    def __init__(self, file_list, batch_size, image_size, \
        shuffle=True, augmentation=None):

        self.file_list = file_list
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.aug = augmentation
        self.on_epoch_end()
    
    def __len__(self):
        return math.ceil(len(self.file_list) / self.batch_size)

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.file_list))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
    
    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*\
            self.batch_size]

        batch = [self.file_list[k] for k in indexes]

        # Create batch list
        batch_x = []
        batch_y = []

        for filename in batch:
            # Load Image
            image = cv2.imread(os.path.join("training_dataset", "images", \
                filename + ".jpg"))

            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Load mask
            mask_land = cv2.imread(os.path.join("training_dataset", \
                "masks", "land", filename + ".jpg"), \
                cv2.IMREAD_GRAYSCALE)

            mask_road = cv2.imread(os.path.join("training_dataset", \
                "masks", "road", filename + ".jpg"), \
                cv2.IMREAD_GRAYSCALE)

            mask = np.dstack((mask_land, mask_road))

            # Resize
            image = cv2.resize(image, self.image_size)
            mask = cv2.resize(mask, self.image_size, \
                interpolation = cv2.INTER_NEAREST)
            
            # Augmentation
            if self.aug is not None:
                augmented = self.aug(image=image, mask=mask)
                image = augmented["image"]
                mask = augmented["mask"]
            
            # Normalize
            image = cv2.normalize(image, None, 0, 1, \
                cv2.NORM_MINMAX, cv2.CV_32F)
            
            mask = cv2.normalize(mask, None, 0, 1, \
                cv2.NORM_MINMAX, cv2.CV_32F)
            
            # Load to batch
            batch_x.append(image)
            batch_y.append(mask)

        # Convert batch as array
        batch_x = np.array(batch_x)
        batch_y = np.array(batch_y)

        return batch_x, batch_y

# %% [markdown]
# Custom Loss Function

# %%
# Loss Function
def dice_loss(y_true, y_pred, num_classes=2):
    smooth = tf.keras.backend.epsilon()
    dice = 0
    for index in range(num_classes):
        y_true_f = tf.keras.backend.flatten(y_true[:,:,:,index])
        y_pred_f = tf.keras.backend.flatten(y_pred[:,:,:,index])
        intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
        union = tf.keras.backend.sum(y_true_f) + \
            tf.keras.backend.sum(y_pred_f)
        dice -= (2. * intersection + smooth) / (union + smooth)
    return dice/num_classes

# %%
def upsampling2d_nearest(x, upsampling_factor_height, upsampling_factor_width):
    w = x.shape[2] * upsampling_factor_width
    h = x.shape[1] * upsampling_factor_height

    return tf.compat.v1.image.resize_nearest_neighbor(x, (h, w))

# %% [markdown]
# Custom MeanIoU

# %%
# Metric Function
class MaxMeanIoU(tf.keras.metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        return super().update_state(tf.argmax(y_true, axis=-1), tf.argmax(y_pred, axis=-1), sample_weight)

# %% [markdown]
# Create Model

# %%
# Create model
def create_model():
    # Variable
    encoder_layers = []

    # Input
    input_shape = (image_size[0], image_size[1], 3)
    inputs = tf.keras.layers.Input(shape=input_shape)
    x = inputs

    # Encoder
    for i in range(n_encoder_decoder):
        filter_number = int(2**(math.log2(initial_filter)+i))
        
        x = tf.keras.layers.Conv2D(filter_number, 3, \
            activation='relu', padding='same')(x)
        
        x = tf.keras.layers.Conv2D(filter_number, 3, \
            activation='relu', padding='same')(x)

        encoder_layers.append(x)
        x = tf.keras.layers.MaxPool2D()(x)

        print(filter_number)

    # Bridge
    filter_number = int(2**(math.log2(initial_filter)+\
        n_encoder_decoder))

    x = tf.keras.layers.Conv2D(filter_number, 3, \
        activation='relu', padding='same')(x)
                
    x = tf.keras.layers.Conv2D(filter_number, 3, \
        activation='relu', padding='same')(x)

    print(filter_number)

    # Decoder
    for i in reversed(range(n_encoder_decoder)):
        filter_number = int(2**(math.log2(initial_filter)+i))
        x = tf.keras.layers.Lambda(upsampling2d_nearest, \
                                   arguments={'upsampling_factor_height': 2, \
                                              'upsampling_factor_width': 2})(x)
        
        x = tf.keras.layers.Concatenate(axis=3)([x, encoder_layers[i]])

        x = tf.keras.layers.Conv2D(filter_number, 3, activation='relu', padding='same')(x)

        x = tf.keras.layers.Conv2D(filter_number, 3, activation='relu', padding='same')(x)

        print(filter_number)
    
    # Output
    outputs = tf.keras.layers.Conv2D(2, 1)(x)
    outputs = tf.keras.layers.Lambda(lambda x: tf.nn.softmax(x))(outputs)

    # Create Optimizer
    opt = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    # Create Loss Function
    loss = dice_loss

    # Create Model
    model = tf.keras.models.Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer = opt, loss = loss, metrics=["accuracy", MaxMeanIoU(num_classes=2)])
    
    return model

# %% [markdown]
# Create Custom Training Callback

# %%
# Create Callback
def create_callback():
    # Tensorboard Callbacks
    logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

    # Checkpoint Callbacks
    Path("checkpoint").mkdir(parents=True, exist_ok=True)
    
    best_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join("checkpoint", "best" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + ".h5"), 
                                                             monitor='max_mean_io_u', verbose=1, save_best_only=True, mode='max')

    # Predict Image Callbacks
    file_writer_cm = tf.summary.create_file_writer(os.path.join(logdir, "predict_output"))
    def predict_epoch(epoch, logs):
        # Load image
        filename = np.random.choice(test_list)
        image = cv2.imread(os.path.join("training_dataset", "images", filename + ".jpg"))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, image_size)
        image = cv2.normalize(image, None, 0, 1, cv2.NORM_MINMAX, cv2.CV_32F)
        
        # Predict mask
        pred = model.predict(np.expand_dims(image, 0))

        # Process mask
        mask = pred.squeeze()
        mask = np.stack((mask,)*3, axis=-1)
        mask[mask >= 0.5] = 1
        mask[mask < 0.5] = 0

        class_land = np.concatenate([image, mask[:, :, 0], image * mask[:, :, 0]], axis = 1)
        class_sky = np.concatenate([image, mask[:, :, 1], image * mask[:, :, 1]], axis = 1)
        
        # Log the image as an image summary.
        with file_writer_cm.as_default():
            tf.summary.image("class_land", np.reshape(class_land, (1, image_size[0], image_size[1]*3, 3)), step=epoch)
            tf.summary.image("class_road", np.reshape(class_sky, (1, image_size[0], image_size[1]*3, 3)), step=epoch)

    # Define per-epoch callback.
    predict_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=predict_epoch)

    return [tensorboard_callback, best_checkpoint_callback, predict_callback]

# %% [markdown]
# Training

# %%
# Training

# Load Data
dataset_path = "training_dataset/images"
file_list = [os.path.splitext(filename)[0] for filename in os.listdir(dataset_path)]

# Data Split
train_list, test_list = train_test_split(file_list, shuffle=True, \
    test_size=test_size, random_state=random_seed)

start = timer()

# Load data
train_generator = data_generator(train_list, \
    batch_size=batch_size, image_size=image_size, \
    augmentation=aug)

val_generator = data_generator(test_list, \
    batch_size=batch_size, image_size=image_size)

loss = []
accuracy = []
mean_io_u = []

# Create model
model = create_model()

# model_path = os.path.join("model/model_3.h5")
# model.load_weights(model_path)

# Train model
model.fit(train_generator, epochs=epoch, \
    validation_data=val_generator,\
    callbacks=create_callback(), max_queue_size=5)

tot_model = len(glob.glob(os.path.join("model", "*.h5")))

model.save('model/model_'+str(tot_model)+'.h5')

# Evaluate Model
result = model.evaluate(val_generator)

loss = result[0]
accuracy = result[1]
mean_io_u = result[2]
# Out:
# 8
# 16
# 8
# Epoch 1/80
# 5/5 [==============================] - ETA: 0s - loss: -0.3798 - accuracy: 0.0953 - max_mean_io_u: 0.0485
# Epoch 1: max_mean_io_u improved from -inf to 0.04855, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 189ms/step
# 5/5 [==============================] - 90s 22s/step - loss: -0.3798 - accuracy: 0.0953 - max_mean_io_u: 0.0485 - val_loss: -0.4003 - val_accuracy: 0.7347 - val_max_mean_io_u: 0.3866
# Epoch 2/80
# 5/5 [==============================] - ETA: 0s - loss: -0.3974 - accuracy: 0.8653 - max_mean_io_u: 0.4422
# Epoch 2: max_mean_io_u improved from 0.04855 to 0.44216, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 100ms/step
# 5/5 [==============================] - 75s 14s/step - loss: -0.3974 - accuracy: 0.8653 - max_mean_io_u: 0.4422 - val_loss: -0.4020 - val_accuracy: 0.9081 - val_max_mean_io_u: 0.4541
# Epoch 3/80
# 5/5 [==============================] - ETA: 0s - loss: -0.3988 - accuracy: 0.9142 - max_mean_io_u: 0.4571
# Epoch 3: max_mean_io_u improved from 0.44216 to 0.45712, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 101ms/step
# 5/5 [==============================] - 73s 14s/step - loss: -0.3988 - accuracy: 0.9142 - max_mean_io_u: 0.4571 - val_loss: -0.4031 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 4/80
# 5/5 [==============================] - ETA: 0s - loss: -0.3998 - accuracy: 0.9145 - max_mean_io_u: 0.4573
# Epoch 4: max_mean_io_u improved from 0.45712 to 0.45726, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 128ms/step
# 5/5 [==============================] - 74s 14s/step - loss: -0.3998 - accuracy: 0.9145 - max_mean_io_u: 0.4573 - val_loss: -0.4040 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 5/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4009 - accuracy: 0.9141 - max_mean_io_u: 0.4571
# Epoch 5: max_mean_io_u did not improve from 0.45726
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 74s 14s/step - loss: -0.4009 - accuracy: 0.9141 - max_mean_io_u: 0.4571 - val_loss: -0.4051 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 6/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4017 - accuracy: 0.9149 - max_mean_io_u: 0.4574
# Epoch 6: max_mean_io_u improved from 0.45726 to 0.45743, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 100ms/step
# 5/5 [==============================] - 73s 18s/step - loss: -0.4017 - accuracy: 0.9149 - max_mean_io_u: 0.4574 - val_loss: -0.4061 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 7/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4034 - accuracy: 0.9138 - max_mean_io_u: 0.4569
# Epoch 7: max_mean_io_u did not improve from 0.45743
# 1/1 [==============================] - 0s 99ms/step
# 5/5 [==============================] - 68s 17s/step - loss: -0.4034 - accuracy: 0.9138 - max_mean_io_u: 0.4569 - val_loss: -0.4072 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 8/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4042 - accuracy: 0.9140 - max_mean_io_u: 0.4570
# Epoch 8: max_mean_io_u did not improve from 0.45743
# 1/1 [==============================] - 0s 104ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.4042 - accuracy: 0.9140 - max_mean_io_u: 0.4570 - val_loss: -0.4081 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 9/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4048 - accuracy: 0.9146 - max_mean_io_u: 0.4573
# Epoch 9: max_mean_io_u did not improve from 0.45743
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 70s 14s/step - loss: -0.4048 - accuracy: 0.9146 - max_mean_io_u: 0.4573 - val_loss: -0.4089 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 10/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4059 - accuracy: 0.9145 - max_mean_io_u: 0.4572
# Epoch 10: max_mean_io_u did not improve from 0.45743
# 1/1 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 69s 13s/step - loss: -0.4059 - accuracy: 0.9145 - max_mean_io_u: 0.4572 - val_loss: -0.4103 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 11/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4068 - accuracy: 0.9149 - max_mean_io_u: 0.4575
# Epoch 11: max_mean_io_u improved from 0.45743 to 0.45747, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 103ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.4068 - accuracy: 0.9149 - max_mean_io_u: 0.4575 - val_loss: -0.4114 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 12/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4082 - accuracy: 0.9143 - max_mean_io_u: 0.4571
# Epoch 12: max_mean_io_u did not improve from 0.45747
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.4082 - accuracy: 0.9143 - max_mean_io_u: 0.4571 - val_loss: -0.4125 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 13/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4097 - accuracy: 0.9144 - max_mean_io_u: 0.4572
# Epoch 13: max_mean_io_u did not improve from 0.45747
# 1/1 [==============================] - 0s 90ms/step
# 5/5 [==============================] - 69s 13s/step - loss: -0.4097 - accuracy: 0.9144 - max_mean_io_u: 0.4572 - val_loss: -0.4145 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 14/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4119 - accuracy: 0.9153 - max_mean_io_u: 0.4576
# Epoch 14: max_mean_io_u improved from 0.45747 to 0.45764, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 67s 17s/step - loss: -0.4119 - accuracy: 0.9153 - max_mean_io_u: 0.4576 - val_loss: -0.4175 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 15/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4163 - accuracy: 0.9134 - max_mean_io_u: 0.4567
# Epoch 15: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.4163 - accuracy: 0.9134 - max_mean_io_u: 0.4567 - val_loss: -0.4230 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 16/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4226 - accuracy: 0.9140 - max_mean_io_u: 0.4570
# Epoch 16: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.4226 - accuracy: 0.9140 - max_mean_io_u: 0.4570 - val_loss: -0.4343 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 17/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4375 - accuracy: 0.9148 - max_mean_io_u: 0.4574
# Epoch 17: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.4375 - accuracy: 0.9148 - max_mean_io_u: 0.4574 - val_loss: -0.4608 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 18/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4724 - accuracy: 0.9135 - max_mean_io_u: 0.4567
# Epoch 18: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 94ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.4724 - accuracy: 0.9135 - max_mean_io_u: 0.4567 - val_loss: -0.4926 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 19/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4912 - accuracy: 0.9142 - max_mean_io_u: 0.4571
# Epoch 19: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 97ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.4912 - accuracy: 0.9142 - max_mean_io_u: 0.4571 - val_loss: -0.4852 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 20/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4854 - accuracy: 0.9147 - max_mean_io_u: 0.4573
# Epoch 20: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 99ms/step
# 5/5 [==============================] - 66s 13s/step - loss: -0.4854 - accuracy: 0.9147 - max_mean_io_u: 0.4573 - val_loss: -0.4832 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 21/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4855 - accuracy: 0.9142 - max_mean_io_u: 0.4571
# Epoch 21: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 89ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.4855 - accuracy: 0.9142 - max_mean_io_u: 0.4571 - val_loss: -0.4867 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 22/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4905 - accuracy: 0.9147 - max_mean_io_u: 0.4574
# Epoch 22: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 105ms/step
# 5/5 [==============================] - 69s 13s/step - loss: -0.4905 - accuracy: 0.9147 - max_mean_io_u: 0.4574 - val_loss: -0.4931 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 23/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4928 - accuracy: 0.9149 - max_mean_io_u: 0.4575
# Epoch 23: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 100ms/step
# 5/5 [==============================] - 66s 16s/step - loss: -0.4928 - accuracy: 0.9149 - max_mean_io_u: 0.4575 - val_loss: -0.4933 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 24/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4919 - accuracy: 0.9138 - max_mean_io_u: 0.4569
# Epoch 24: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 113ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.4919 - accuracy: 0.9138 - max_mean_io_u: 0.4569 - val_loss: -0.4936 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 25/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4935 - accuracy: 0.9143 - max_mean_io_u: 0.4571
# Epoch 25: max_mean_io_u did not improve from 0.45764
# 1/1 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 66s 13s/step - loss: -0.4935 - accuracy: 0.9143 - max_mean_io_u: 0.4571 - val_loss: -0.4943 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 26/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4945 - accuracy: 0.9154 - max_mean_io_u: 0.4577
# Epoch 26: max_mean_io_u improved from 0.45764 to 0.45772, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 91ms/step
# 5/5 [==============================] - 66s 13s/step - loss: -0.4945 - accuracy: 0.9154 - max_mean_io_u: 0.4577 - val_loss: -0.4943 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 27/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4947 - accuracy: 0.9138 - max_mean_io_u: 0.4569
# Epoch 27: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.4947 - accuracy: 0.9138 - max_mean_io_u: 0.4569 - val_loss: -0.4956 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 28/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4961 - accuracy: 0.9133 - max_mean_io_u: 0.4566
# Epoch 28: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 96ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.4961 - accuracy: 0.9133 - max_mean_io_u: 0.4566 - val_loss: -0.4970 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 29/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4974 - accuracy: 0.9138 - max_mean_io_u: 0.4569
# Epoch 29: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 92ms/step
# 5/5 [==============================] - 66s 12s/step - loss: -0.4974 - accuracy: 0.9138 - max_mean_io_u: 0.4569 - val_loss: -0.4988 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 30/80
# 5/5 [==============================] - ETA: 0s - loss: -0.4996 - accuracy: 0.9147 - max_mean_io_u: 0.4573
# Epoch 30: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 97ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.4996 - accuracy: 0.9147 - max_mean_io_u: 0.4573 - val_loss: -0.5007 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 31/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5011 - accuracy: 0.9142 - max_mean_io_u: 0.4571
# Epoch 31: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 66s 13s/step - loss: -0.5011 - accuracy: 0.9142 - max_mean_io_u: 0.4571 - val_loss: -0.5032 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 32/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5050 - accuracy: 0.9137 - max_mean_io_u: 0.4569
# Epoch 32: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.5050 - accuracy: 0.9137 - max_mean_io_u: 0.4569 - val_loss: -0.5077 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 33/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5110 - accuracy: 0.9143 - max_mean_io_u: 0.4571
# Epoch 33: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 71s 13s/step - loss: -0.5110 - accuracy: 0.9143 - max_mean_io_u: 0.4571 - val_loss: -0.5136 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 34/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5179 - accuracy: 0.9152 - max_mean_io_u: 0.4576
# Epoch 34: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 94ms/step
# 5/5 [==============================] - 69s 13s/step - loss: -0.5179 - accuracy: 0.9152 - max_mean_io_u: 0.4576 - val_loss: -0.5237 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 35/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5312 - accuracy: 0.9136 - max_mean_io_u: 0.4568
# Epoch 35: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.5312 - accuracy: 0.9136 - max_mean_io_u: 0.4568 - val_loss: -0.5410 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 36/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5513 - accuracy: 0.9135 - max_mean_io_u: 0.4567
# Epoch 36: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.5513 - accuracy: 0.9135 - max_mean_io_u: 0.4567 - val_loss: -0.5584 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 37/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5721 - accuracy: 0.9150 - max_mean_io_u: 0.4575
# Epoch 37: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.5721 - accuracy: 0.9150 - max_mean_io_u: 0.4575 - val_loss: -0.5816 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 38/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5860 - accuracy: 0.9131 - max_mean_io_u: 0.4565
# Epoch 38: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 90ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.5860 - accuracy: 0.9131 - max_mean_io_u: 0.4565 - val_loss: -0.5975 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 39/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6000 - accuracy: 0.9142 - max_mean_io_u: 0.4571
# Epoch 39: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 91ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6000 - accuracy: 0.9142 - max_mean_io_u: 0.4571 - val_loss: -0.6076 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 40/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5973 - accuracy: 0.9136 - max_mean_io_u: 0.4568
# Epoch 40: max_mean_io_u did not improve from 0.45772
# 1/1 [==============================] - 0s 92ms/step
# 5/5 [==============================] - 67s 16s/step - loss: -0.5973 - accuracy: 0.9136 - max_mean_io_u: 0.4568 - val_loss: -0.6055 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 41/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6163 - accuracy: 0.9157 - max_mean_io_u: 0.4579
# Epoch 41: max_mean_io_u improved from 0.45772 to 0.45785, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.6163 - accuracy: 0.9157 - max_mean_io_u: 0.4579 - val_loss: -0.6054 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 42/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6160 - accuracy: 0.9159 - max_mean_io_u: 0.4579
# Epoch 42: max_mean_io_u improved from 0.45785 to 0.45793, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.6160 - accuracy: 0.9159 - max_mean_io_u: 0.4579 - val_loss: -0.5800 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 43/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5823 - accuracy: 0.9148 - max_mean_io_u: 0.4574
# Epoch 43: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 97ms/step
# 5/5 [==============================] - 69s 13s/step - loss: -0.5823 - accuracy: 0.9148 - max_mean_io_u: 0.4574 - val_loss: -0.6208 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 44/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6091 - accuracy: 0.9145 - max_mean_io_u: 0.4573
# Epoch 44: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6091 - accuracy: 0.9145 - max_mean_io_u: 0.4573 - val_loss: -0.5777 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 45/80
# 5/5 [==============================] - ETA: 0s - loss: -0.5915 - accuracy: 0.9146 - max_mean_io_u: 0.4573
# Epoch 45: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 97ms/step
# 5/5 [==============================] - 68s 17s/step - loss: -0.5915 - accuracy: 0.9146 - max_mean_io_u: 0.4573 - val_loss: -0.6220 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 46/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6118 - accuracy: 0.9152 - max_mean_io_u: 0.4576
# Epoch 46: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 94ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6118 - accuracy: 0.9152 - max_mean_io_u: 0.4576 - val_loss: -0.5967 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 47/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6193 - accuracy: 0.9139 - max_mean_io_u: 0.4569
# Epoch 47: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 101ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6193 - accuracy: 0.9139 - max_mean_io_u: 0.4569 - val_loss: -0.6165 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 48/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6177 - accuracy: 0.9135 - max_mean_io_u: 0.4568
# Epoch 48: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 97ms/step
# 5/5 [==============================] - 70s 13s/step - loss: -0.6177 - accuracy: 0.9135 - max_mean_io_u: 0.4568 - val_loss: -0.6150 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 49/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6256 - accuracy: 0.9147 - max_mean_io_u: 0.4574
# Epoch 49: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 100ms/step
# 5/5 [==============================] - 70s 13s/step - loss: -0.6256 - accuracy: 0.9147 - max_mean_io_u: 0.4574 - val_loss: -0.6262 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 50/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6303 - accuracy: 0.9140 - max_mean_io_u: 0.4570
# Epoch 50: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 96ms/step
# 5/5 [==============================] - 70s 13s/step - loss: -0.6303 - accuracy: 0.9140 - max_mean_io_u: 0.4570 - val_loss: -0.6285 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 51/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6307 - accuracy: 0.9133 - max_mean_io_u: 0.4566
# Epoch 51: max_mean_io_u did not improve from 0.45793
# 1/1 [==============================] - 0s 116ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6307 - accuracy: 0.9133 - max_mean_io_u: 0.4566 - val_loss: -0.6224 - val_accuracy: 0.9082 - val_max_mean_io_u: 0.4541
# Epoch 52/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6300 - accuracy: 0.9140 - max_mean_io_u: 0.5139
# Epoch 52: max_mean_io_u improved from 0.45793 to 0.51390, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 90ms/step
# 5/5 [==============================] - 69s 17s/step - loss: -0.6300 - accuracy: 0.9140 - max_mean_io_u: 0.5139 - val_loss: -0.6304 - val_accuracy: 0.9048 - val_max_mean_io_u: 0.5976
# Epoch 53/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6342 - accuracy: 0.8877 - max_mean_io_u: 0.5867
# Epoch 53: max_mean_io_u improved from 0.51390 to 0.58674, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 123ms/step
# 5/5 [==============================] - 70s 13s/step - loss: -0.6342 - accuracy: 0.8877 - max_mean_io_u: 0.5867 - val_loss: -0.6295 - val_accuracy: 0.8501 - val_max_mean_io_u: 0.5644
# Epoch 54/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6418 - accuracy: 0.8788 - max_mean_io_u: 0.5887
# Epoch 54: max_mean_io_u improved from 0.58674 to 0.58872, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6418 - accuracy: 0.8788 - max_mean_io_u: 0.5887 - val_loss: -0.6455 - val_accuracy: 0.9016 - val_max_mean_io_u: 0.5973
# Epoch 55/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6521 - accuracy: 0.9117 - max_mean_io_u: 0.6013
# Epoch 55: max_mean_io_u improved from 0.58872 to 0.60127, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 111ms/step
# 5/5 [==============================] - 70s 13s/step - loss: -0.6521 - accuracy: 0.9117 - max_mean_io_u: 0.6013 - val_loss: -0.6605 - val_accuracy: 0.9033 - val_max_mean_io_u: 0.5980
# Epoch 56/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6737 - accuracy: 0.8957 - max_mean_io_u: 0.5986
# Epoch 56: max_mean_io_u did not improve from 0.60127
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6737 - accuracy: 0.8957 - max_mean_io_u: 0.5986 - val_loss: -0.6730 - val_accuracy: 0.8850 - val_max_mean_io_u: 0.5880
# Epoch 57/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6673 - accuracy: 0.9198 - max_mean_io_u: 0.5950
# Epoch 57: max_mean_io_u did not improve from 0.60127
# 1/1 [==============================] - 0s 102ms/step
# 5/5 [==============================] - 69s 17s/step - loss: -0.6673 - accuracy: 0.9198 - max_mean_io_u: 0.5950 - val_loss: -0.6687 - val_accuracy: 0.9213 - val_max_mean_io_u: 0.5917
# Epoch 58/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6898 - accuracy: 0.9174 - max_mean_io_u: 0.6040
# Epoch 58: max_mean_io_u improved from 0.60127 to 0.60401, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6898 - accuracy: 0.9174 - max_mean_io_u: 0.6040 - val_loss: -0.6760 - val_accuracy: 0.8568 - val_max_mean_io_u: 0.5703
# Epoch 59/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6884 - accuracy: 0.8788 - max_mean_io_u: 0.5850
# Epoch 59: max_mean_io_u did not improve from 0.60401
# 1/1 [==============================] - 0s 112ms/step
# 5/5 [==============================] - 69s 13s/step - loss: -0.6884 - accuracy: 0.8788 - max_mean_io_u: 0.5850 - val_loss: -0.6986 - val_accuracy: 0.9075 - val_max_mean_io_u: 0.5999
# Epoch 60/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6971 - accuracy: 0.9188 - max_mean_io_u: 0.6033
# Epoch 60: max_mean_io_u did not improve from 0.60401
# 1/1 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 69s 13s/step - loss: -0.6971 - accuracy: 0.9188 - max_mean_io_u: 0.6033 - val_loss: -0.6958 - val_accuracy: 0.9138 - val_max_mean_io_u: 0.5992
# Epoch 61/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7065 - accuracy: 0.9149 - max_mean_io_u: 0.6077
# Epoch 61: max_mean_io_u improved from 0.60401 to 0.60770, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 99ms/step
# 5/5 [==============================] - 69s 17s/step - loss: -0.7065 - accuracy: 0.9149 - max_mean_io_u: 0.6077 - val_loss: -0.6934 - val_accuracy: 0.8872 - val_max_mean_io_u: 0.5910
# Epoch 62/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7059 - accuracy: 0.8943 - max_mean_io_u: 0.6022
# Epoch 62: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 97ms/step
# 5/5 [==============================] - 70s 13s/step - loss: -0.7059 - accuracy: 0.8943 - max_mean_io_u: 0.6022 - val_loss: -0.6924 - val_accuracy: 0.9028 - val_max_mean_io_u: 0.5937
# Epoch 63/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7049 - accuracy: 0.9064 - max_mean_io_u: 0.6064
# Epoch 63: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.7049 - accuracy: 0.9064 - max_mean_io_u: 0.6064 - val_loss: -0.6850 - val_accuracy: 0.8578 - val_max_mean_io_u: 0.5724
# Epoch 64/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6941 - accuracy: 0.8727 - max_mean_io_u: 0.5829
# Epoch 64: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 93ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.6941 - accuracy: 0.8727 - max_mean_io_u: 0.5829 - val_loss: -0.7015 - val_accuracy: 0.9109 - val_max_mean_io_u: 0.6001
# Epoch 65/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6763 - accuracy: 0.9199 - max_mean_io_u: 0.5865
# Epoch 65: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.6763 - accuracy: 0.9199 - max_mean_io_u: 0.5865 - val_loss: -0.6880 - val_accuracy: 0.9210 - val_max_mean_io_u: 0.5942
# Epoch 66/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7003 - accuracy: 0.9139 - max_mean_io_u: 0.6028
# Epoch 66: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 100ms/step
# 5/5 [==============================] - 67s 17s/step - loss: -0.7003 - accuracy: 0.9139 - max_mean_io_u: 0.6028 - val_loss: -0.6971 - val_accuracy: 0.8817 - val_max_mean_io_u: 0.5889
# Epoch 67/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7015 - accuracy: 0.8880 - max_mean_io_u: 0.5954
# Epoch 67: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 100ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.7015 - accuracy: 0.8880 - max_mean_io_u: 0.5954 - val_loss: -0.7001 - val_accuracy: 0.8986 - val_max_mean_io_u: 0.5992
# Epoch 68/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7071 - accuracy: 0.9117 - max_mean_io_u: 0.6052
# Epoch 68: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 66s 13s/step - loss: -0.7071 - accuracy: 0.9117 - max_mean_io_u: 0.6052 - val_loss: -0.7051 - val_accuracy: 0.8991 - val_max_mean_io_u: 0.6001
# Epoch 69/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7056 - accuracy: 0.8956 - max_mean_io_u: 0.5998
# Epoch 69: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 97ms/step
# 5/5 [==============================] - 66s 13s/step - loss: -0.7056 - accuracy: 0.8956 - max_mean_io_u: 0.5998 - val_loss: -0.7049 - val_accuracy: 0.9079 - val_max_mean_io_u: 0.6046
# Epoch 70/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7026 - accuracy: 0.9108 - max_mean_io_u: 0.6039
# Epoch 70: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 96ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.7026 - accuracy: 0.9108 - max_mean_io_u: 0.6039 - val_loss: -0.6905 - val_accuracy: 0.8632 - val_max_mean_io_u: 0.5771
# Epoch 71/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7052 - accuracy: 0.8931 - max_mean_io_u: 0.5997
# Epoch 71: max_mean_io_u did not improve from 0.60770
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.7052 - accuracy: 0.8931 - max_mean_io_u: 0.5997 - val_loss: -0.7025 - val_accuracy: 0.9114 - val_max_mean_io_u: 0.6042
# Epoch 72/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7115 - accuracy: 0.9106 - max_mean_io_u: 0.6081
# Epoch 72: max_mean_io_u improved from 0.60770 to 0.60805, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 94ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.7115 - accuracy: 0.9106 - max_mean_io_u: 0.6081 - val_loss: -0.6662 - val_accuracy: 0.8268 - val_max_mean_io_u: 0.5482
# Epoch 73/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6126 - accuracy: 0.7591 - max_mean_io_u: 0.4844
# Epoch 73: max_mean_io_u did not improve from 0.60805
# 1/1 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 66s 16s/step - loss: -0.6126 - accuracy: 0.7591 - max_mean_io_u: 0.4844 - val_loss: -0.6773 - val_accuracy: 0.8427 - val_max_mean_io_u: 0.5608
# Epoch 74/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7016 - accuracy: 0.8857 - max_mean_io_u: 0.5925
# Epoch 74: max_mean_io_u did not improve from 0.60805
# 1/1 [==============================] - 0s 98ms/step
# 5/5 [==============================] - 67s 16s/step - loss: -0.7016 - accuracy: 0.8857 - max_mean_io_u: 0.5925 - val_loss: -0.7064 - val_accuracy: 0.9072 - val_max_mean_io_u: 0.6028
# Epoch 75/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6904 - accuracy: 0.9203 - max_mean_io_u: 0.5961
# Epoch 75: max_mean_io_u did not improve from 0.60805
# 1/1 [==============================] - 0s 99ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.6904 - accuracy: 0.9203 - max_mean_io_u: 0.5961 - val_loss: -0.6944 - val_accuracy: 0.9199 - val_max_mean_io_u: 0.5986
# Epoch 76/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7126 - accuracy: 0.9163 - max_mean_io_u: 0.6157
# Epoch 76: max_mean_io_u improved from 0.60805 to 0.61567, saving model to checkpoint\best20230609-213046.h5
# 1/1 [==============================] - 0s 91ms/step
# 5/5 [==============================] - 68s 13s/step - loss: -0.7126 - accuracy: 0.9163 - max_mean_io_u: 0.6157 - val_loss: -0.6953 - val_accuracy: 0.8715 - val_max_mean_io_u: 0.5846
# Epoch 77/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6954 - accuracy: 0.8791 - max_mean_io_u: 0.5897
# Epoch 77: max_mean_io_u did not improve from 0.61567
# 1/1 [==============================] - 0s 101ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.6954 - accuracy: 0.8791 - max_mean_io_u: 0.5897 - val_loss: -0.6996 - val_accuracy: 0.8974 - val_max_mean_io_u: 0.5961
# Epoch 78/80
# 5/5 [==============================] - ETA: 0s - loss: -0.7062 - accuracy: 0.8952 - max_mean_io_u: 0.6017
# Epoch 78: max_mean_io_u did not improve from 0.61567
# 1/1 [==============================] - 0s 95ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.7062 - accuracy: 0.8952 - max_mean_io_u: 0.6017 - val_loss: -0.6864 - val_accuracy: 0.8698 - val_max_mean_io_u: 0.5802
# Epoch 79/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6926 - accuracy: 0.8724 - max_mean_io_u: 0.5822
# Epoch 79: max_mean_io_u did not improve from 0.61567
# 1/1 [==============================] - 0s 99ms/step
# 5/5 [==============================] - 67s 13s/step - loss: -0.6926 - accuracy: 0.8724 - max_mean_io_u: 0.5822 - val_loss: -0.6889 - val_accuracy: 0.8689 - val_max_mean_io_u: 0.5787
# Epoch 80/80
# 5/5 [==============================] - ETA: 0s - loss: -0.6999 - accuracy: 0.9185 - max_mean_io_u: 0.6020
# Epoch 80: max_mean_io_u did not improve from 0.61567
# 1/1 [==============================] - 0s 116ms/step
# 5/5 [==============================] - 67s 17s/step - loss: -0.6999 - accuracy: 0.9185 - max_mean_io_u: 0.6020 - val_loss: -0.6701 - val_accuracy: 0.9207 - val_max_mean_io_u: 0.5787
# 2/2 [==============================] - 4s 132ms/step - loss: -0.6687 - accuracy: 0.9207 - max_mean_io_u: 0.5787

# %% [markdown]
# Print Result

# %%
# Get evaluation metric
print("Run Date:", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
print("Elapsed Time:", timer() - start, "Seconds")
print("Training parameter")
print("test_size:", test_size)
print("random_seed:", random_seed)
print()
print("Hyperparameter:")
print("epoch:", epoch)
print("batch_size:", batch_size)
print("learning_rate:", learning_rate)
print("n_encoder_decoder:", n_encoder_decoder)
print("initial_filter:", initial_filter)
print()
print("Result:")
print("loss:", loss)
print("accuracy:", accuracy)
print("mean_io_u:", mean_io_u)
# Out:
# Run Date: 20230609-230211
# Elapsed Time: 5485.372406721115 Seconds
# Training parameter
# test_size: 0.2
# random_seed: 42
#
# Hyperparameter:
# epoch: 80
# batch_size: 32
# learning_rate: 0.001
# n_encoder_decoder: 1
# initial_filter: 8
#
# Result:
# loss: -0.6686517596244812
# accuracy: 0.9207482933998108
# mean_io_u: 0.5787200927734375
